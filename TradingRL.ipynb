# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
# Out:
# 2025-04-02 18:22:30.591396: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743618150.611528   26583 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743618150.618332   26583 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743618150.633618   26583 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743618150.633637   26583 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743618150.633639   26583 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743618150.633641   26583 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-02 18:22:30.638296: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# ======================
# Technical Indicators
# ======================
def compute_rsi(prices, window=14):
    delta = prices.diff()
    gain = delta.where(delta > 0, 0).fillna(0)
    loss = -delta.where(delta < 0, 0).fillna(0)
    
    avg_gain = gain.rolling(window=window).mean()
    avg_loss = loss.rolling(window=window).mean()
    
    rs = avg_gain / (avg_loss + 1e-10)
    return 100 - (100 / (1 + rs))

def compute_bollinger_bands(prices, window=20):
    sma = prices.rolling(window=window).mean()
    std = prices.rolling(window=window).std()
    return sma + 2 * std, sma - 2 * std

def compute_macd(prices, fast=12, slow=26, signal=9):
    ema_fast = prices.ewm(span=fast, adjust=False).mean()
    ema_slow = prices.ewm(span=slow, adjust=False).mean()
    macd = ema_fast - ema_slow
    signal_line = macd.ewm(span=signal, adjust=False).mean()
    return macd, signal_line

# %%
# ======================
# Trading Environment (Gymnasium)
# ======================
class AdvancedTradingEnv(gym.Env):
    def __init__(self, df, initial_balance=10000, transaction_fee=0.001, window_size=30):
        super().__init__()
        
        self.df = df
        self.initial_balance = initial_balance
        self.transaction_fee = transaction_fee
        self.window_size = window_size
        
        # Action space
        self.action_space = spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        
        # Observation space
        self.observation_space = spaces.Box(
            low=-np.inf, 
            high=np.inf, 
            shape=(10,),
            dtype=np.float32
        )
        
        self.reset()

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = self.window_size
        self.balance = self.initial_balance
        self.position = 0.0
        self.portfolio_history = [self.initial_balance] * self.window_size
        self.peak_portfolio = self.initial_balance
        self.max_drawdown = 0.0
        return self._next_observation(), {}

    def _next_observation(self):
        window_data = self.df.iloc[self.current_step - self.window_size:self.current_step]
        
        # Explicit scalar extraction
        close_price = float(window_data['Close'].iloc[-1])
        sma_20 = float(window_data['SMA_20'].iloc[-1])
        rsi = float(window_data['RSI_14'].iloc[-1])
        upper_bb = float(window_data['Upper_BB'].iloc[-1])
        lower_bb = float(window_data['Lower_BB'].iloc[-1])
        macd = float(window_data['MACD'].iloc[-1])
        macd_signal = float(window_data['MACD_Signal'].iloc[-1])
        volume = float(window_data['Volume'].iloc[-1])
        volume_ma5 = float(window_data['Volume_MA5'].iloc[-1])
        
        features = np.array([
            close_price / sma_20 - 1,
            (rsi - 50) / 50,
            (upper_bb - lower_bb) / sma_20,
            macd - macd_signal,
            (volume - volume_ma5) / (np.std(window_data['Volume'].values[-5:]) + 1e-10),
            self.balance / self.initial_balance,
            self.position * close_price / self.initial_balance,
            np.log(close_price / float(window_data['Close'].iloc[-5])),
            np.log(volume / float(window_data['Volume'].iloc[-5])),
            self.max_drawdown
        ], dtype=np.float32)
        
        return features

    def step(self, action):
        current_price = float(self.df['Close'].iloc[self.current_step])
        prev_portfolio = self.portfolio_history[-1]
        
        # Execute action
        trade_value = action[0] * self.balance
        fee = abs(trade_value) * self.transaction_fee
        
        if trade_value > 0:  # Buy
            max_affordable = (self.balance - fee) / current_price
            units_bought = min(trade_value / current_price, max_affordable)
            self.position += units_bought
            self.balance -= units_bought * current_price + fee
        elif trade_value < 0:  # Sell
            units_sold = min(abs(trade_value) / current_price, self.position)
            self.position -= units_sold
            self.balance += units_sold * current_price - fee

        # Update portfolio
        portfolio_value = self.balance + self.position * current_price
        self.portfolio_history.append(portfolio_value)
        
        # Risk metrics
        self.peak_portfolio = max(self.peak_portfolio, portfolio_value)
        current_drawdown = (self.peak_portfolio - portfolio_value) / self.peak_portfolio
        self.max_drawdown = max(self.max_drawdown, current_drawdown)
        
        # Calculate returns
        # Calculate returns CORRECTED VERSION
        hist_window = np.array(self.portfolio_history[-self.window_size:])
        if len(hist_window) >= 2:  # Ensure we have enough data
            returns = np.diff(hist_window) / hist_window[:-1]
        else:
            returns = np.array([0.0])
        sharpe_ratio = np.mean(returns) / (np.std(returns) + 1e-10) * np.sqrt(252)
        
        # Reward components
        reward = (portfolio_value - prev_portfolio) + \
                0.2 * sharpe_ratio - \
                0.5 * self.max_drawdown - \
                0.1 * fee
        
        # Move to next step
        self.current_step += 1
        done = self.current_step >= len(self.df) - 1
        
        return self._next_observation(), reward, done, False, {}

# %%
# ======================
# Data Preparation
# ======================
def prepare_data(symbol="BTC-USD", start="2018-01-01", end="2024-01-01"):
    df = yf.download(symbol, start=start, end=end)
    
    # Calculate indicators
    df['SMA_20'] = df['Close'].rolling(20).mean()
    df['RSI_14'] = compute_rsi(df['Close'])
    df['Upper_BB'], df['Lower_BB'] = compute_bollinger_bands(df['Close'])
    df['MACD'], df['MACD_Signal'] = compute_macd(df['Close'])
    df['Volume_MA5'] = df['Volume'].rolling(5).mean()
    
    # Validate data
    df = df.dropna()
    df = df.astype(np.float32)
    
    return df

# %%
# ======================
# Training & Evaluation
# ======================
def train_model(df, window_size=365, total_timesteps=100000):
    env = make_vec_env(lambda: AdvancedTradingEnv(df), n_envs=4)
    
    model = PPO(
        "MlpPolicy",
        env,
        verbose=1,
        learning_rate=3e-4,
        n_steps=2048,
        batch_size=64,
        gamma=0.99,
        device="auto"
    )
    
    # Rolling window training
    for i in range(0, len(df) - window_size, window_size//2):
        window_df = df.iloc[i:i+window_size]
        env = make_vec_env(lambda: AdvancedTradingEnv(window_df), n_envs=4)
        model.set_env(env)
        model.learn(total_timesteps=total_timesteps, reset_num_timesteps=False)
        
    return model

# %%
def evaluate_model(model, test_df):
    env = AdvancedTradingEnv(test_df)
    obs, _ = env.reset()
    done = False
    
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _, _ = env.step(action)
    
    final_value = env.balance + env.position * test_df['Close'].iloc[-1]
    buy_hold_value = env.initial_balance * (test_df['Close'].iloc[-1] / test_df['Close'].iloc[0])
    
    print(f"\n{' Final Results ':=^40}")
    print(f"RL Portfolio Value: ${final_value.values[0]:,.2f}")  # Alternative method
    print(f"Buy & Hold Value:   ${buy_hold_value.values[0]:,.2f}")
    print(f"Max Drawdown:       {env.max_drawdown*100:.2f}%")
    print("="*40)

# %%
# ======================
# Main Execution
# ======================
if __name__ == "__main__":
    full_data = prepare_data()
    train_df = full_data.iloc[:-365]
    test_df = full_data.iloc[-365:]
    
    model = train_model(train_df)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Using cuda device
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 334       |
# |    ep_rew_mean     | -6.79e+03 |
# | time/              |           |
# |    fps             | 223       |
# |    iterations      | 1         |
# |    time_elapsed    | 36        |
# |    total_timesteps | 8192      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -6.82e+03    |
# | time/                   |              |
# |    fps                  | 208          |
# |    iterations           | 2            |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0032131022 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.000167     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.11e+05     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00116     |
# |    std                  | 0.995        |
# |    value_loss           | 5.13e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -6.78e+03    |
# | time/                   |              |
# |    fps                  | 205          |
# |    iterations           | 3            |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0012350022 |
# |    clip_fraction        | 0.00719      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.000556     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.4e+05      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000145    |
# |    std                  | 0.994        |
# |    value_loss           | 4.81e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -6.78e+03    |
# | time/                   |              |
# |    fps                  | 204          |
# |    iterations           | 4            |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0015515928 |
# |    clip_fraction        | 0.00482      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 4.89e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.65e+05     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | 0.000181     |
# |    std                  | 0.98         |
# |    value_loss           | 5.03e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -6.77e+03    |
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 5            |
# |    time_elapsed         | 201          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0008966849 |
# |    clip_fraction        | 0.00334      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 1.25e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71e+05     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -7.88e-05    |
# |    std                  | 0.989        |
# |    value_loss           | 4.87e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 334        |
# |    ep_rew_mean          | -6.75e+03  |
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 6          |
# |    time_elapsed         | 242        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00921483 |
# |    clip_fraction        | 0.0341     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 5.96e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.54e+05   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | 0.0013     |
# |    std                  | 0.993      |
# |    value_loss           | 4.77e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | -6.78e+03   |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 7           |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.000521376 |
# |    clip_fraction        | 0.00266     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 7.15e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.93e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -7.49e-05   |
# |    std                  | 0.99        |
# |    value_loss           | 4.73e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -6.76e+03     |
# | time/                   |               |
# |    fps                  | 201           |
# |    iterations           | 8             |
# |    time_elapsed         | 325           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00091932365 |
# |    clip_fraction        | 0.000952      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.000466      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.85e+05      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000129     |
# |    std                  | 1             |
# |    value_loss           | 4.76e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -6.76e+03    |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 9            |
# |    time_elapsed         | 366          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0025479367 |
# |    clip_fraction        | 0.00951      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.00239      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.49e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000911    |
# |    std                  | 1.01         |
# |    value_loss           | 5.01e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -6.76e+03    |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 10           |
# |    time_elapsed         | 408          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0024886515 |
# |    clip_fraction        | 0.00094      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0205       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.63e+05     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000313    |
# |    std                  | 1.01         |
# |    value_loss           | 4.75e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -6.75e+03    |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 11           |
# |    time_elapsed         | 449          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0018201931 |
# |    clip_fraction        | 0.0017       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0273       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.38e+05     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000392    |
# |    std                  | 1.01         |
# |    value_loss           | 4.67e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -6.77e+03    |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 12           |
# |    time_elapsed         | 491          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0031254212 |
# |    clip_fraction        | 0.00355      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0.0336       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.82e+05     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000305    |
# |    std                  | 1.01         |
# |    value_loss           | 4.7e+05      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -6.75e+03     |
# | time/                   |               |
# |    fps                  | 199           |
# |    iterations           | 13            |
# |    time_elapsed         | 533           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 1.8226929e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.0393        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.82e+05      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | 5.88e-06      |
# |    std                  | 1.01          |
# |    value_loss           | 4.62e+05      |
# -------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 334       |
# |    ep_rew_mean     | -3.64e+03 |
# | time/              |           |
# |    fps             | 217       |
# |    iterations      | 1         |
# |    time_elapsed    | 37        |
# |    total_timesteps | 114688    |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | -497        |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 2           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.000250476 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.00115    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.74e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -7.06e-05   |
# |    std                  | 1           |
# |    value_loss           | 1.63e+06    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 2.58e+03      |
# | time/                   |               |
# |    fps                  | 200           |
# |    iterations           | 3             |
# |    time_elapsed         | 122           |
# |    total_timesteps      | 131072        |
# | train/                  |               |
# |    approx_kl            | 0.00028713682 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.0248        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.38e+05      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.00029      |
# |    std                  | 1             |
# |    value_loss           | 1.54e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 5.71e+03     |
# | time/                   |              |
# |    fps                  | 199          |
# |    iterations           | 4            |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 8.421921e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.39e+05     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -5.21e-06    |
# |    std                  | 1            |
# |    value_loss           | 1.48e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 6.26e+03      |
# | time/                   |               |
# |    fps                  | 198           |
# |    iterations           | 5             |
# |    time_elapsed         | 206           |
# |    total_timesteps      | 147456        |
# | train/                  |               |
# |    approx_kl            | 3.8289072e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.169         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.07e+05      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -6.33e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.5e+06       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 6.23e+03      |
# | time/                   |               |
# |    fps                  | 198           |
# |    iterations           | 6             |
# |    time_elapsed         | 247           |
# |    total_timesteps      | 155648        |
# | train/                  |               |
# |    approx_kl            | 3.3843455e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.198         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.38e+05      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -4.3e-05      |
# |    std                  | 1             |
# |    value_loss           | 1.46e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 6.23e+03     |
# | time/                   |              |
# |    fps                  | 198          |
# |    iterations           | 7            |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 5.256632e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.222        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.66e+05     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -4.2e-05     |
# |    std                  | 0.999        |
# |    value_loss           | 1.47e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 6.24e+03      |
# | time/                   |               |
# |    fps                  | 198           |
# |    iterations           | 8             |
# |    time_elapsed         | 330           |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 0.00016917122 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.239         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.13e+05      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000185     |
# |    std                  | 1             |
# |    value_loss           | 1.51e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 6.25e+03      |
# | time/                   |               |
# |    fps                  | 198           |
# |    iterations           | 9             |
# |    time_elapsed         | 371           |
# |    total_timesteps      | 180224        |
# | train/                  |               |
# |    approx_kl            | 7.4929994e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.258         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.07e+05      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -8.51e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.44e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 6.18e+03      |
# | time/                   |               |
# |    fps                  | 198           |
# |    iterations           | 10            |
# |    time_elapsed         | 412           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 6.0956554e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.274         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.04e+05      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -2.23e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.43e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 6.17e+03      |
# | time/                   |               |
# |    fps                  | 198           |
# |    iterations           | 11            |
# |    time_elapsed         | 453           |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 2.1949309e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.292         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.33e+05      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | 8.35e-07      |
# |    std                  | 1             |
# |    value_loss           | 1.42e+06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | 6.19e+03    |
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 12          |
# |    time_elapsed         | 494         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.000100933 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.37e+05    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -8.86e-05   |
# |    std                  | 1           |
# |    value_loss           | 1.4e+06     |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 6.22e+03      |
# | time/                   |               |
# |    fps                  | 198           |
# |    iterations           | 13            |
# |    time_elapsed         | 536           |
# |    total_timesteps      | 212992        |
# | train/                  |               |
# |    approx_kl            | 0.00055638456 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.311         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.47e+05      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000207     |
# |    std                  | 0.999         |
# |    value_loss           | 1.41e+06      |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 334      |
# |    ep_rew_mean     | 7.78e+03 |
# | time/              |          |
# |    fps             | 223      |
# |    iterations      | 1        |
# |    time_elapsed    | 36       |
# |    total_timesteps | 221184   |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 9.36e+03      |
# | time/                   |               |
# |    fps                  | 210           |
# |    iterations           | 2             |
# |    time_elapsed         | 77            |
# |    total_timesteps      | 229376        |
# | train/                  |               |
# |    approx_kl            | 4.2505344e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.00134       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.25e+06      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -2.29e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.71e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 1.09e+04      |
# | time/                   |               |
# |    fps                  | 205           |
# |    iterations           | 3             |
# |    time_elapsed         | 119           |
# |    total_timesteps      | 237568        |
# | train/                  |               |
# |    approx_kl            | 2.3101165e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.152         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.19e+06      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -9.7e-08      |
# |    std                  | 1             |
# |    value_loss           | 4.88e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 1.23e+04      |
# | time/                   |               |
# |    fps                  | 203           |
# |    iterations           | 4             |
# |    time_elapsed         | 161           |
# |    total_timesteps      | 245760        |
# | train/                  |               |
# |    approx_kl            | 1.0403164e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.166         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.8e+06       |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -7.11e-07     |
# |    std                  | 1             |
# |    value_loss           | 4.88e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 1.26e+04      |
# | time/                   |               |
# |    fps                  | 202           |
# |    iterations           | 5             |
# |    time_elapsed         | 202           |
# |    total_timesteps      | 253952        |
# | train/                  |               |
# |    approx_kl            | 3.7100253e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.186         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.43e+06      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -2.17e-05     |
# |    std                  | 1             |
# |    value_loss           | 4.75e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 1.26e+04      |
# | time/                   |               |
# |    fps                  | 201           |
# |    iterations           | 6             |
# |    time_elapsed         | 243           |
# |    total_timesteps      | 262144        |
# | train/                  |               |
# |    approx_kl            | 1.0478325e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.199         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.02e+06      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -6.75e-06     |
# |    std                  | 1             |
# |    value_loss           | 4.67e+06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 1.26e+04      |
# | time/                   |               |
# |    fps                  | 200           |
# |    iterations           | 7             |
# |    time_elapsed         | 285           |
# |    total_timesteps      | 270336        |
# | train/                  |               |
# |    approx_kl            | 2.0994776e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.208         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.32e+06      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -2.26e-06     |
# |    std                  | 1             |
# |    value_loss           | 4.65e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 1.27e+04     |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 8            |
# |    time_elapsed         | 327          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 9.195355e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.219        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.65e+06     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -1.61e-06    |
# |    std                  | 1            |
# |    value_loss           | 4.63e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 1.28e+04     |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 9            |
# |    time_elapsed         | 368          |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 4.069443e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.227        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.71e+06     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -2.57e-05    |
# |    std                  | 1            |
# |    value_loss           | 4.69e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | 1.27e+04    |
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 10          |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 6.44628e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.67e+06    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -1.21e-05   |
# |    std                  | 1           |
# |    value_loss           | 4.52e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 1.27e+04     |
# | time/                   |              |
# |    fps                  | 199          |
# |    iterations           | 11           |
# |    time_elapsed         | 450          |
# |    total_timesteps      | 303104       |
# | train/                  |              |
# |    approx_kl            | 1.800072e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.245        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.13e+06     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -8.51e-07    |
# |    std                  | 0.999        |
# |    value_loss           | 4.62e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 1.26e+04     |
# | time/                   |              |
# |    fps                  | 199          |
# |    iterations           | 12           |
# |    time_elapsed         | 491          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 1.546141e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.08e+06     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 2.93e-07     |
# |    std                  | 0.999        |
# |    value_loss           | 4.65e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 1.25e+04      |
# | time/                   |               |
# |    fps                  | 199           |
# |    iterations           | 13            |
# |    time_elapsed         | 533           |
# |    total_timesteps      | 319488        |
# | train/                  |               |
# |    approx_kl            | 3.3112883e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.261         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.16e+06      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -5.34e-06     |
# |    std                  | 0.999         |
# |    value_loss           | 4.44e+06      |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 334      |
# |    ep_rew_mean     | 9.16e+03 |
# | time/              |          |
# |    fps             | 226      |
# |    iterations      | 1        |
# |    time_elapsed    | 36       |
# |    total_timesteps | 327680   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 5.82e+03     |
# | time/                   |              |
# |    fps                  | 211          |
# |    iterations           | 2            |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 335872       |
# | train/                  |              |
# |    approx_kl            | 0.0007560968 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.00288     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.35e+05     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000434    |
# |    std                  | 1            |
# |    value_loss           | 5.46e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | 2.5e+03       |
# | time/                   |               |
# |    fps                  | 206           |
# |    iterations           | 3             |
# |    time_elapsed         | 119           |
# |    total_timesteps      | 344064        |
# | train/                  |               |
# |    approx_kl            | 1.0137883e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.176         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.96e+05      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -7.88e-06     |
# |    std                  | 1             |
# |    value_loss           | 5.17e+05      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 334            |
# |    ep_rew_mean          | -823           |
# | time/                   |                |
# |    fps                  | 204            |
# |    iterations           | 4              |
# |    time_elapsed         | 160            |
# |    total_timesteps      | 352256         |
# | train/                  |                |
# |    approx_kl            | 1.13159695e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | 0.51           |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.57e+05       |
# |    n_updates            | 420            |
# |    policy_gradient_loss | -7.9e-05       |
# |    std                  | 1              |
# |    value_loss           | 3.6e+05        |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -1.4e+03     |
# | time/                   |              |
# |    fps                  | 203          |
# |    iterations           | 5            |
# |    time_elapsed         | 201          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 5.888658e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.569        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67e+05     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -3.89e-05    |
# |    std                  | 1            |
# |    value_loss           | 3.45e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -1.43e+03     |
# | time/                   |               |
# |    fps                  | 202           |
# |    iterations           | 6             |
# |    time_elapsed         | 242           |
# |    total_timesteps      | 368640        |
# | train/                  |               |
# |    approx_kl            | 1.2973178e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.605         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.07e+05      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -3.13e-06     |
# |    std                  | 1             |
# |    value_loss           | 3.23e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -1.45e+03    |
# | time/                   |              |
# |    fps                  | 201          |
# |    iterations           | 7            |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 8.331961e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.15e+05     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -3.97e-05    |
# |    std                  | 1            |
# |    value_loss           | 3.06e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -1.47e+03    |
# | time/                   |              |
# |    fps                  | 201          |
# |    iterations           | 8            |
# |    time_elapsed         | 325          |
# |    total_timesteps      | 385024       |
# | train/                  |              |
# |    approx_kl            | 3.371184e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.659        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+05     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -2.23e-05    |
# |    std                  | 1            |
# |    value_loss           | 2.62e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -1.47e+03     |
# | time/                   |               |
# |    fps                  | 201           |
# |    iterations           | 9             |
# |    time_elapsed         | 366           |
# |    total_timesteps      | 393216        |
# | train/                  |               |
# |    approx_kl            | 1.0118834e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.668         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.96e+04      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -4.15e-05     |
# |    std                  | 1             |
# |    value_loss           | 2.72e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -1.45e+03     |
# | time/                   |               |
# |    fps                  | 201           |
# |    iterations           | 10            |
# |    time_elapsed         | 407           |
# |    total_timesteps      | 401408        |
# | train/                  |               |
# |    approx_kl            | 3.4364348e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.686         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.2e+05       |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -2.05e-06     |
# |    std                  | 1             |
# |    value_loss           | 2.6e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -1.45e+03     |
# | time/                   |               |
# |    fps                  | 200           |
# |    iterations           | 11            |
# |    time_elapsed         | 448           |
# |    total_timesteps      | 409600        |
# | train/                  |               |
# |    approx_kl            | 4.1739186e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.7           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.58e+05      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -4.9e-06      |
# |    std                  | 1             |
# |    value_loss           | 2.51e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -1.42e+03     |
# | time/                   |               |
# |    fps                  | 199           |
# |    iterations           | 12            |
# |    time_elapsed         | 491           |
# |    total_timesteps      | 417792        |
# | train/                  |               |
# |    approx_kl            | 6.7769724e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.712         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.33e+05      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -1.5e-06      |
# |    std                  | 1             |
# |    value_loss           | 2.36e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -1.4e+03      |
# | time/                   |               |
# |    fps                  | 199           |
# |    iterations           | 13            |
# |    time_elapsed         | 533           |
# |    total_timesteps      | 425984        |
# | train/                  |               |
# |    approx_kl            | 1.7978091e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0.718         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.13e+05      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -5.14e-06     |
# |    std                  | 1             |
# |    value_loss           | 2.38e+05      |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 334      |
# |    ep_rew_mean     | 5.57e+03 |
# | time/              |          |
# |    fps             | 223      |
# |    iterations      | 1        |
# |    time_elapsed    | 36       |
# |    total_timesteps | 434176   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | 1.26e+04     |
# | time/                   |              |
# |    fps                  | 209          |
# ...
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.62e+05      |
# |    n_updates            | 860           |
# |    policy_gradient_loss | -3.67e-07     |
# |    std                  | 0.993         |
# |    value_loss           | 6.38e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -1.5e+03     |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 10           |
# |    time_elapsed         | 408          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 9.844371e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.651        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.5e+05      |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -2.92e-07    |
# |    std                  | 0.993        |
# |    value_loss           | 5.35e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -1.43e+03    |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 11           |
# |    time_elapsed         | 449          |
# |    total_timesteps      | 729088       |
# | train/                  |              |
# |    approx_kl            | 7.930794e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.623        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.56e+05     |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -1.43e-08    |
# |    std                  | 0.993        |
# |    value_loss           | 6.22e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -1.44e+03     |
# | time/                   |               |
# |    fps                  | 200           |
# |    iterations           | 12            |
# |    time_elapsed         | 490           |
# |    total_timesteps      | 737280        |
# | train/                  |               |
# |    approx_kl            | 1.7731509e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.631         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.86e+05      |
# |    n_updates            | 890           |
# |    policy_gradient_loss | -9.25e-07     |
# |    std                  | 0.993         |
# |    value_loss           | 6.3e+05       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -1.37e+03     |
# | time/                   |               |
# |    fps                  | 200           |
# |    iterations           | 13            |
# |    time_elapsed         | 531           |
# |    total_timesteps      | 745472        |
# | train/                  |               |
# |    approx_kl            | 9.3568815e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.637         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.34e+05      |
# |    n_updates            | 900           |
# |    policy_gradient_loss | -6.3e-08      |
# |    std                  | 0.993         |
# |    value_loss           | 6.04e+05      |
# -------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 334       |
# |    ep_rew_mean     | -2.38e+03 |
# | time/              |           |
# |    fps             | 223       |
# |    iterations      | 1         |
# |    time_elapsed    | 36        |
# |    total_timesteps | 753664    |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -3.44e+03    |
# | time/                   |              |
# |    fps                  | 210          |
# |    iterations           | 2            |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 761856       |
# | train/                  |              |
# |    approx_kl            | 8.694769e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.223        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.66e+05     |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -1.24e-07    |
# |    std                  | 0.993        |
# |    value_loss           | 6.31e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -4.45e+03     |
# | time/                   |               |
# |    fps                  | 206           |
# |    iterations           | 3             |
# |    time_elapsed         | 119           |
# |    total_timesteps      | 770048        |
# | train/                  |               |
# |    approx_kl            | 1.0484655e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.326         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.22e+05      |
# |    n_updates            | 930           |
# |    policy_gradient_loss | -1.51e-07     |
# |    std                  | 0.993         |
# |    value_loss           | 6.24e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -5.48e+03     |
# | time/                   |               |
# |    fps                  | 202           |
# |    iterations           | 4             |
# |    time_elapsed         | 161           |
# |    total_timesteps      | 778240        |
# | train/                  |               |
# |    approx_kl            | 1.3547833e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.353         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.25e+05      |
# |    n_updates            | 940           |
# |    policy_gradient_loss | -2.83e-07     |
# |    std                  | 0.993         |
# |    value_loss           | 6.42e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -5.64e+03     |
# | time/                   |               |
# |    fps                  | 202           |
# |    iterations           | 5             |
# |    time_elapsed         | 202           |
# |    total_timesteps      | 786432        |
# | train/                  |               |
# |    approx_kl            | 5.4496923e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.368         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.85e+05      |
# |    n_updates            | 950           |
# |    policy_gradient_loss | 6.99e-08      |
# |    std                  | 0.993         |
# |    value_loss           | 6.24e+05      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | -5.65e+03   |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 6           |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 794624      |
# | train/                  |             |
# |    approx_kl            | 9.26957e-09 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.76e+05    |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -3e-08      |
# |    std                  | 0.993       |
# |    value_loss           | 6.11e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -5.63e+03    |
# | time/                   |              |
# |    fps                  | 201          |
# |    iterations           | 7            |
# |    time_elapsed         | 284          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 9.655196e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.443        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.9e+05      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -1.13e-07    |
# |    std                  | 0.993        |
# |    value_loss           | 5.88e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -5.63e+03     |
# | time/                   |               |
# |    fps                  | 201           |
# |    iterations           | 8             |
# |    time_elapsed         | 325           |
# |    total_timesteps      | 811008        |
# | train/                  |               |
# |    approx_kl            | 3.3825927e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.467         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.63e+05      |
# |    n_updates            | 980           |
# |    policy_gradient_loss | -2.57e-06     |
# |    std                  | 0.993         |
# |    value_loss           | 6.22e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -5.63e+03    |
# | time/                   |              |
# |    fps                  | 201          |
# |    iterations           | 9            |
# |    time_elapsed         | 366          |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 6.679329e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.519        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.65e+05     |
# |    n_updates            | 990          |
# |    policy_gradient_loss | 3.93e-08     |
# |    std                  | 0.993        |
# |    value_loss           | 5.48e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -5.62e+03     |
# | time/                   |               |
# |    fps                  | 200           |
# |    iterations           | 10            |
# |    time_elapsed         | 408           |
# |    total_timesteps      | 827392        |
# | train/                  |               |
# |    approx_kl            | 1.0404619e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.541         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.57e+05      |
# |    n_updates            | 1000          |
# |    policy_gradient_loss | -1.46e-07     |
# |    std                  | 0.993         |
# |    value_loss           | 6.33e+05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -5.62e+03     |
# | time/                   |               |
# |    fps                  | 200           |
# |    iterations           | 11            |
# |    time_elapsed         | 449           |
# |    total_timesteps      | 835584        |
# | train/                  |               |
# |    approx_kl            | 1.9841536e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.538         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.73e+05      |
# |    n_updates            | 1010          |
# |    policy_gradient_loss | -9.66e-07     |
# |    std                  | 0.993         |
# |    value_loss           | 6.16e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 334          |
# |    ep_rew_mean          | -5.62e+03    |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 12           |
# |    time_elapsed         | 490          |
# |    total_timesteps      | 843776       |
# | train/                  |              |
# |    approx_kl            | 4.775211e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.561        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.42e+05     |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -3.55e-06    |
# |    std                  | 0.993        |
# |    value_loss           | 6.15e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 334           |
# |    ep_rew_mean          | -5.61e+03     |
# | time/                   |               |
# |    fps                  | 200           |
# |    iterations           | 13            |
# |    time_elapsed         | 532           |
# |    total_timesteps      | 851968        |
# | train/                  |               |
# |    approx_kl            | 3.6874553e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0.567         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.37e+05      |
# |    n_updates            | 1030          |
# |    policy_gradient_loss | -2.49e-06     |
# |    std                  | 0.993         |
# |    value_loss           | 5.94e+05      |
# -------------------------------------------

# %%
    evaluate_model(model, test_df)
    model.save("rl_trading_model_final")
# Out:
# ============ Final Results =============
# RL Portfolio Value: $18,152.04
# Buy & Hold Value:   $25,422.55
# Max Drawdown:       20.06%
# ========================================
